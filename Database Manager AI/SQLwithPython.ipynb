# %% [markdown]
# ### AI AGENT FOR SQL DATABASE ASSISTANCE

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
print(os.getenv("GROQ_API_KEY"))
# Out:
# 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

# %%
from langchain_groq import ChatGroq
from langchain.agents import AgentType
from langchain.agents import create_sql_agent
from pathlib import Path
from langchain.sql_database import SQLDatabase
from langchain.agents.agent_toolkits import SQLDatabaseToolkit
from sqlalchemy import create_engine
import sqlite3

# %%
llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
dbfile = f"{Path.cwd().parent}/student.db"
creator = lambda: sqlite3.connect(f"file:{dbfile}?mode=ro", uri=True)

db = SQLDatabase(create_engine('sqlite:///', creator=creator))

# %%
toolkit = SQLDatabaseToolkit(db=db,llm=llm)

# %%
agent = create_sql_agent(llm,toolkit,verbose=True,agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION)

# %%
agent.invoke("list of student whose hobbies are related to sports")
# Out:
# > Entering new SQL Agent Executor chain...
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 agent.invoke("list of student whose hobbies are related to sports")
#
# File d:\Langchain\venv\lib\site-packages\langchain\chains\base.py:165, in Chain.invoke(self, input, config, **kwargs)
#     162 try:
#     163     self._validate_inputs(inputs)
#     164     outputs = (
# --> 165         self._call(inputs, run_manager=run_manager)
#     166         if new_arg_supported
#     167         else self._call(inputs)
#     168     )
#     170     final_outputs: dict[str, Any] = self.prep_outputs(
#     171         inputs,
#     172         outputs,
#     173         return_only_outputs,
#     174     )
#     175 except BaseException as e:
#
# File d:\Langchain\venv\lib\site-packages\langchain\agents\agent.py:1625, in AgentExecutor._call(self, inputs, run_manager)
#    1623 # We now enter the agent loop (until it returns something).
#    1624 while self._should_continue(iterations, time_elapsed):
# -> 1625     next_step_output = self._take_next_step(
#    1626         name_to_tool_map,
#    1627         color_mapping,
#    1628         inputs,
#    1629         intermediate_steps,
#    1630         run_manager=run_manager,
#    1631     )
#    1632     if isinstance(next_step_output, AgentFinish):
#    1633         return self._return(
#    1634             next_step_output,
#    1635             intermediate_steps,
#    1636             run_manager=run_manager,
#    1637         )
#
# File d:\Langchain\venv\lib\site-packages\langchain\agents\agent.py:1325, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1316 def _take_next_step(
#    1317     self,
#    1318     name_to_tool_map: dict[str, BaseTool],
#    (...)
#    1322     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1323 ) -> Union[AgentFinish, list[tuple[AgentAction, str]]]:
#    1324     return self._consume_next_step(
# -> 1325         list(
#    1326             self._iter_next_step(
#    1327                 name_to_tool_map,
#    1328                 color_mapping,
#    1329                 inputs,
#    1330                 intermediate_steps,
#    1331                 run_manager,
#    1332             ),
#    1333         ),
#    1334     )
#
# File d:\Langchain\venv\lib\site-packages\langchain\agents\agent.py:1352, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1349     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#    1351     # Call the LLM to see what to do.
# -> 1352     output = self._action_agent.plan(
#    1353         intermediate_steps,
#    1354         callbacks=run_manager.get_child() if run_manager else None,
#    1355         **inputs,
#    1356     )
#    1357 except OutputParserException as e:
#    1358     if isinstance(self.handle_parsing_errors, bool):
#
# File d:\Langchain\venv\lib\site-packages\langchain\agents\agent.py:455, in RunnableAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     447 final_output: Any = None
#     448 if self.stream_runnable:
#     449     # Use streaming to make sure that the underlying LLM is invoked in a
#     450     # streaming
#    (...)
#     453     # Because the response from the plan is not a generator, we need to
#     454     # accumulate the output into final output and return that.
# --> 455     for chunk in self.runnable.stream(inputs, config={"callbacks": callbacks}):
#     456         if final_output is None:
#     457             final_output = chunk
#
# File d:\Langchain\venv\lib\site-packages\langchain_core\runnables\base.py:3649, in RunnableSequence.stream(self, input, config, **kwargs)
#    3642 @override
#    3643 def stream(
#    3644     self,
#    (...)
#    3647     **kwargs: Optional[Any],
#    3648 ) -> Iterator[Output]:
# -> 3649     yield from self.transform(iter([input]), config, **kwargs)
#
# File d:\Langchain\venv\lib\site-packages\langchain_core\runnables\base.py:3635, in RunnableSequence.transform(self, input, config, **kwargs)
#    3628 @override
#    3629 def transform(
#    3630     self,
#    (...)
#    3633     **kwargs: Optional[Any],
#    3634 ) -> Iterator[Output]:
# -> 3635     yield from self._transform_stream_with_config(
#    3636         input,
#    3637         self._transform,
#    3638         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3639         **kwargs,
#    3640     )
#
# File d:\Langchain\venv\lib\site-packages\langchain_core\runnables\base.py:2369, in Runnable._transform_stream_with_config(self, inputs, transformer, config, run_type, **kwargs)
#    2367 try:
#    2368     while True:
# -> 2369         chunk: Output = context.run(next, iterator)
#    2370         yield chunk
#    2371         if final_output_supported:
#
# File d:\Langchain\venv\lib\site-packages\langchain_core\runnables\base.py:3594, in RunnableSequence._transform(self, inputs, run_manager, config, **kwargs)
#    3591     else:
#    3592         final_pipeline = step.transform(final_pipeline, config)
# -> 3594 yield from final_pipeline
#
# File d:\Langchain\venv\lib\site-packages\langchain_core\runnables\base.py:1568, in Runnable.transform(self, input, config, **kwargs)
#    1565 final: Input
#    1566 got_first_val = False
# -> 1568 for ichunk in input:
#    1569     # The default implementation of transform is to buffer input and
#    1570     # then call stream.
#    1571     # It'll attempt to gather all input into a single chunk using
#    1572     # the `+` operator.
#    1573     # If the input is not addable, then we'll assume that we can
#    1574     # only operate on the last chunk,
#    1575     # and we'll iterate until we get to the last chunk.
#    1576     if not got_first_val:
#    1577         final = ichunk
#
# File d:\Langchain\venv\lib\site-packages\langchain_core\runnables\base.py:5926, in RunnableBindingBase.transform(self, input, config, **kwargs)
#    5919 @override
#    5920 def transform(
#    5921     self,
#    (...)
#    5924     **kwargs: Any,
#    5925 ) -> Iterator[Output]:
# -> 5926     yield from self.bound.transform(
#    5927         input,
#    5928         self._merge_configs(config),
#    5929         **{**self.kwargs, **kwargs},
#    5930     )
#
# File d:\Langchain\venv\lib\site-packages\langchain_core\runnables\base.py:1586, in Runnable.transform(self, input, config, **kwargs)
#    1583             final = ichunk
#    1585 if got_first_val:
# -> 1586     yield from self.stream(final, config, **kwargs)
#
# File d:\Langchain\venv\lib\site-packages\langchain_core\language_models\chat_models.py:522, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     520 input_messages = _normalize_messages(messages)
#     521 run_id = "-".join((_LC_ID_PREFIX, str(run_manager.run_id)))
# --> 522 for chunk in self._stream(input_messages, stop=stop, **kwargs):
#     523     if chunk.message.id is None:
#     524         chunk.message.id = run_id
#
# File d:\Langchain\venv\lib\site-packages\langchain_groq\chat_models.py:569, in ChatGroq._stream(self, messages, stop, run_manager, **kwargs)
#     566 params = {**params, **kwargs, "stream": True}
#     568 default_chunk_class: type[BaseMessageChunk] = AIMessageChunk
# --> 569 for chunk in self.client.create(messages=message_dicts, **params):
#     570     if not isinstance(chunk, dict):
#     571         chunk = chunk.model_dump()
#
# File d:\Langchain\venv\lib\site-packages\groq\resources\chat\completions.py:448, in Completions.create(self, messages, model, compound_custom, documents, exclude_domains, frequency_penalty, function_call, functions, include_domains, include_reasoning, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     238 def create(
#     239     self,
#     240     *,
#    (...)
#     295     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     296 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     297     """
#     298     Creates a model response for the given chat conversation.
#     299
#    (...)
#     446       timeout: Override the client-level default timeout for this request, in seconds
#     447     """
# --> 448     return self._post(
#     449         "/openai/v1/chat/completions",
#     450         body=maybe_transform(
#     451             {
#     452                 "messages": messages,
#     453                 "model": model,
#     454                 "compound_custom": compound_custom,
#     455                 "documents": documents,
#     456                 "exclude_domains": exclude_domains,
#     457                 "frequency_penalty": frequency_penalty,
#     458                 "function_call": function_call,
#     459                 "functions": functions,
#     460                 "include_domains": include_domains,
#     461                 "include_reasoning": include_reasoning,
#     462                 "logit_bias": logit_bias,
#     463                 "logprobs": logprobs,
#     464                 "max_completion_tokens": max_completion_tokens,
#     465                 "max_tokens": max_tokens,
#     466                 "metadata": metadata,
#     467                 "n": n,
#     468                 "parallel_tool_calls": parallel_tool_calls,
#     469                 "presence_penalty": presence_penalty,
#     470                 "reasoning_effort": reasoning_effort,
#     471                 "reasoning_format": reasoning_format,
#     472                 "response_format": response_format,
#     473                 "search_settings": search_settings,
#     474                 "seed": seed,
#     475                 "service_tier": service_tier,
#     476                 "stop": stop,
#     477                 "store": store,
#     478                 "stream": stream,
#     479                 "temperature": temperature,
#     480                 "tool_choice": tool_choice,
#     481                 "tools": tools,
#     482                 "top_logprobs": top_logprobs,
#     483                 "top_p": top_p,
#     484                 "user": user,
#     485             },
#     486             completion_create_params.CompletionCreateParams,
#     487         ),
#     488         options=make_request_options(
#     489             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     490         ),
#     491         cast_to=ChatCompletion,
#     492         stream=stream or False,
#     493         stream_cls=Stream[ChatCompletionChunk],
#     494     )
#
# File d:\Langchain\venv\lib\site-packages\groq\_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)
#    1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Langchain\venv\lib\site-packages\groq\_base_client.py:1044, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1041             err.response.read()
#    1043         log.debug("Re-raising status error")
# -> 1044         raise self._make_status_error_from_response(err.response) from None
#    1046     break
#    1048 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Invalid API Key', 'type': 'invalid_request_error', 'code': 'invalid_api_key'}}
